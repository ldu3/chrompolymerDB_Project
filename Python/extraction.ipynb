# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# file_path = "../Data/chr1.27120000.27895000/hic.clean.1/hic.clean.csv.gz"
file_path = "../Data/chr2.230805000.231690000/hic.clean.1/hic.clean.csv.gz"
df = pd.read_csv(file_path)

df
# Out:
#         i1   j1        fq  pval  fdr  bon        ibp        jbp         rawc
# 0       14   44  0.307160   0.0  0.0  0.0  230870000  231020000    82.357970
# 1       14   45  0.246168   0.0  0.0  0.0  230870000  231025000    79.109290
# 2       58   64  0.799956   0.0  0.0  0.0  231090000  231120000   131.982510
# 3       58   66  0.562411   0.0  0.0  0.0  231090000  231130000   105.293290
# 4       58  133  0.137885   0.0  0.0  0.0  231090000  231465000    62.791737
# ...    ...  ...       ...   ...  ...  ...        ...        ...          ...
# 15748  175  176  1.000000   1.0  1.0  1.0  231675000  231680000   488.386380
# 15749  175  177  1.000000   1.0  1.0  1.0  231675000  231685000   208.631030
# 15750  176  176  1.000000   1.0  1.0  1.0  231680000  231680000  1276.108300
# 15751  176  177  1.000000   1.0  1.0  1.0  231680000  231685000   401.953520
# 15752  177  177  1.000000   1.0  1.0  1.0  231685000  231685000  1080.796800
#
# [15753 rows x 9 columns]

# %%
pivot_table = df.pivot(index="i1", columns="j1", values="fq")

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, fmt=".2f", cmap="YlOrBr", cbar_kws={'label': 'quantile normalized frequency(fq)'})
plt.title('Quantile Normalized Frequency(fq)')
plt.xlabel('j1')
plt.ylabel('i1')
plt.show()
